# %%
from io import BytesIO
from zipfile import ZipFile
from urllib.request import urlopen
import json
from pycocotools.coco import COCO
from pathlib import Path
import requests
from tqdm import tqdm
from threading import Thread
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# %matplotlib inline

# %%
def download_annotations(coco_dir,year=2017,annotation_type="instances"):
    """Downloads Coco training and validation annotations for given year and type.
    Inputs:
    coco_dir: Directory where data should be extracted. Will create an annotations
    folder if one doesn't already exists.
    year: should be either 2014 or 2017 depending on desired dataset.
    annotation_type: can be any of instances, keypoints or captions depending on task.
    Returns: PosixPath for training and validation annotation files.
    """
    if isinstance(coco_dir,str):
        coco_dir = Path(coco_dir)
     
    year = str(year)
    
    print("checking if annotations already exist...")
    
    annotation_dir = coco_dir/'annotations'
    if not annotation_dir.is_dir():
        annotation_dir.mkdir()
        print(f"{annotation_dir} directory not found, created it.")
    
    train_pth_exists = [s for s in annotation_dir.iterdir() if annotation_type+"_train"+year in str(s)]
    val_pth_exists = [s for s in annotation_dir.iterdir() if annotation_type+"_val"+year in str(s)]
    
    if len(train_pth_exists)>0 and len(val_pth_exists)>0:
        print(f"found annotations for type '{annotation_type}' from {year} COCO dataset on disk")
        print("Done.")
        return train_pth_exists[0],val_pth_exists[0]
    
    print(f"downloading annotations for type '{annotation_type}' from {year} COCO dataset...")
    
    resp = urlopen(f'http://images.cocodataset.org/annotations/annotations_trainval{year}.zip')
    zipfile = ZipFile(BytesIO(resp.read()))
    
    for filename in zipfile.namelist():
        if annotation_type in filename:
            filepath = coco_dir/filename
            print(f"saving annotations to {filepath}")
            
            if "train" in filename:
                train_pth = filepath
            elif "val" in filename:
                val_pth = filepath
                
            with zipfile.open(filename) as f:
                data = f.read()
                d = json.loads(data)
                with open(filepath, "w") as fout:
                    fout.write(json.dumps(d))
    
    print("Done.")
    return train_pth, val_pth

# %%
def download_img(url, fname, dest='', store=None):
    if isinstance(dest,str):
        dest = Path(dest)
        
    if store is None:
            store = []
        
    img_data = requests.get(url).content
    filepath = dest/fname
    with open(filepath, 'wb') as handler:
        handler.write(img_data)
        store.append(filepath)
    
    return store

# %%
def download_coco_images(images, dest, nthreads=50):
    store = []
    threads = []
    im_to_dl = []
    
    print("Checking dest for already existing images...")
    for im in images:
        filepath = dest/im['file_name']
        if filepath.exists():
            store.append(filepath)
        else:
            im_to_dl.append(im)
        
    if len(im_to_dl)==0:
        print("All images already exist on disk")
        return store
    
    #threads > 50 will be stale
    if nthreads>50:
        print("setting nthreads to 50 as maximum allowed")
        nthreads=50
        
    # create the threads
    for i in range(nthreads):
        img_grp = im_to_dl[i::nthreads]
        for im in img_grp:
            t = Thread(target=download_img, 
                       args=(im['coco_url'],im['file_name'],dest,store))
            threads.append(t)

    # start the threads
    print("assigning requests to threads...")
    [t.start() for t in threads]
    # wait for the threads to finish
    print("downloading images..")
    [t.join() for t in tqdm(threads)]

    return store

# %%
def plt_coco(images):
    idxs = np.random.randint(len(images),size=4)
    
    fig = plt.figure()
    for i in range(4):
        img = images[idxs[i]]
        fig.set_size_inches(16, 8)
        ax = fig.add_subplot(2, 2, i+1)
        I = mpimg.imread(coco_dir/('images/'+img['file_name']))
        plt.imshow(I); plt.axis('off')

        annIds = coco.getAnnIds([img['id']], catIds, iscrowd=None)
        anns = coco.loadAnns(annIds)
        coco.showAnns(anns)

# %%
COCO_DIR = "coco"

# %%
coco_dir = Path(COCO_DIR)

# %%
download_annotations(COCO_DIR,2014,'captions')
download_annotations(COCO_DIR,2017,'captions')
# Out:
# checking if annotations already exist...
# found annotations for type 'captions' from 2014 COCO dataset on disk
# Done.
# checking if annotations already exist...
# found annotations for type 'captions' from 2017 COCO dataset on disk
# Done.
# (PosixPath('coco/annotations/captions_train2017.json'),
#  PosixPath('coco/annotations/captions_val2017.json'))

# %%
# instantiate COCO specifying the annotations json path
coco = COCO('coco/annotations/instances_val2014.json')
# Out:
# loading annotations into memory...
# Done (t=25.03s)
# creating index...
# index created!

# %%
# Specify a list of category names of interest
catIds = coco.getCatIds(catNms=['person','train'])

# %%
catIds
# Out:
# [1, 7]

# %%
# Get the corresponding image ids and images using loadImgs
imgIds = coco.getImgIds(catIds=catIds)
images = coco.loadImgs(imgIds)

# %%
download_coco_images(images,coco_dir/'images')
# Out:
# Checking dest for already existing images...
# All images already exist on disk
# [PosixPath('coco/images/COCO_val2014_000000032777.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000290827.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000456730.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000047131.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000088094.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000057377.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000245793.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000006180.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000503845.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000483374.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000051249.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000231476.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000518197.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000501824.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000550980.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000127044.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000227399.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000403531.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000241747.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000149588.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000297046.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000544855.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000421978.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000415840.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000532580.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000227433.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000014450.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000276596.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000147577.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000219260.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000065661.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000235644.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000327807.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000405632.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000456833.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000503939.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000034950.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000450695.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000508041.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000014473.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000344205.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000290959.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000387216.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000106641.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000145562.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000082085.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000061605.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000323751.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000026802.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000426175.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000032960.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000393411.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000383175.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000086220.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000432332.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000170190.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000344271.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000528595.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000116951.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000116957.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000483550.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000217312.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000114920.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000080104.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000096488.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000352491.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000579818.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000565485.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000055545.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000469242.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000475387.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000469246.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000186624.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000080130.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000157955.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000555267.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000129285.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000393478.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000004359.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000258311.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000581899.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000231691.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000399628.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000250127.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000545040.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000043286.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000426268.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000180510.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000444703.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000299295.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000235808.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000143653.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000074030.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000053550.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000342318.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000297267.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000217400.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000442681.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000086334.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000338255.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000448849.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000174420.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000178516.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000078170.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000344415.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000260447.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000571746.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000203110.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000139623.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000340329.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000113001.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000221547.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000414068.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000332153.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000209274.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000158084.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000117125.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000577924.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000219525.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000391560.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000532876.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000215439.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000151956.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000403862.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000276886.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000547224.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000330140.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000133537.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000453029.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000563641.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000518586.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000012731.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000201148.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000104893.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000412094.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000125375.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000090560.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000344513.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000133567.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000047552.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000281028.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000145862.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000086472.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000268745.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000418251.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000174544.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000436691.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000315863.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000270810.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000451046.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000209388.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000436722.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000557559.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000532983.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000131581.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000137727.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000295426.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000451077.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000031240.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000023051.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000277005.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000074256.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000565778.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000260627.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000410141.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000068128.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000459303.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000010793.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000084521.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000578093.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000193069.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000340529.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000528951.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000442942.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000283203.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000029253.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000516681.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000125513.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000150091.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000533069.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000027226.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000471642.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000025181.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000391774.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000404071.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000125547.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000035436.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000070254.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000375409.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000567922.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000363134.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000352895.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000006789.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000307847.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000481928.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000012947.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000248468.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000342675.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000316054.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000021147.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000465566.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000223905.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000514722.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000498339.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000127659.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000559790.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000434867.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000471737.jpg'),
#  PosixPath('coco/images/COCO_val2014_000
jpg'),
#  PosixPath('coco/images/COCO_val2014_000000198510.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000520047.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000362352.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000419697.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000143217.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000575348.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000546687.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000393093.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000133000.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000456584.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000253835.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000331667.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000257940.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000006040.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000178072.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000448410.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000450458.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000020381.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000358301.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000036768.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000032673.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000049060.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000401320.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000130984.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000350122.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000399274.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000069553.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000575410.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000223157.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000456638.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000462784.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000575428.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000495557.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000378825.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000438220.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000419790.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000212945.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000294865.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000438232.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000270297.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000196571.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000200668.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000346083.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000428004.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000028646.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000497640.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000528364.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000471023.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000096241.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000172021.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000120826.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000313342.jpg'),
#  PosixPath('coco/images/COCO_val2014_000000511999.jpg')]

# %%
plt_coco(images)

# %%
mask = coco.annToMask(anns[0])
# for i in range(len(anns)):
#     mask += coco.annToMask(anns[i])
plt.imshow(mask)

# %%
def map_source_class_id(self, source_class_id):
    """Takes a source class ID and returns the int class ID assigned to it.
    For example:
    dataset.map_source_class_id("coco.12") -> 23
    """
    return self.class_from_source_map[source_class_id]

def load_mask(self, image_id):
    """Load instance masks for the given image.
    Different datasets use different ways to store masks. This
    function converts the different mask format to one format
    in the form of a bitmap [height, width, instances].
    Returns:
    masks: A bool array of shape [height, width, instance count] with
        one mask per instance.
    class_ids: a 1D array of class IDs of the instance masks.
    """
    # If not a COCO image, delegate to parent class.
    image_info = self.image_info[image_id]
    if image_info["source"] != "coco":
        return super(CocoDataset, self).load_mask(image_id)

    instance_masks = []
    class_ids = []
    annotations = self.image_info[image_id]["annotations"]
    # Build mask of shape [height, width, instance_count] and list
    # of class IDs that correspond to each channel of the mask.
    for annotation in annotations:
        class_id = self.map_source_class_id(
            "coco.{}".format(annotation['category_id']))
        if class_id:
            m = self.annToMask(annotation, image_info["height"],
                               image_info["width"])
            # Some objects are so small that they're less than 1 pixel area
            # and end up rounded out. Skip those objects.
            if m.max() < 1:
                continue
            # Is it a crowd? If so, use a negative class ID.
            if annotation['iscrowd']:
                # Use negative class ID for crowds
                class_id *= -1
                # For crowd masks, annToMask() sometimes returns a mask
                # smaller than the given dimensions. If so, resize it.
                if m.shape[0] != image_info["height"] or m.shape[1] != image_info["width"]:
                    m = np.ones([image_info["height"], image_info["width"]], dtype=bool)
            instance_masks.append(m)
            class_ids.append(class_id)

    # Pack instance masks into an array
    if class_ids:
        mask = np.stack(instance_masks, axis=2)
        class_ids = np.array(class_ids, dtype=np.int32)
        return mask, class_ids
    else:
        # Call super class to return an empty mask
        return super(CocoDataset, self).load_mask(image_id)

def annToRLE(self, ann, height, width):
    """
    Convert annotation which can be polygons, uncompressed RLE to RLE.
    :return: binary mask (numpy 2D array)
    """
    segm = ann['segmentation']
    if isinstance(segm, list):
        # polygon -- a single object might consist of multiple parts
        # we merge all parts into one mask rle code
        rles = maskUtils.frPyObjects(segm, height, width)
        rle = maskUtils.merge(rles)
    elif isinstance(segm['counts'], list):
        # uncompressed RLE
        rle = maskUtils.frPyObjects(segm, height, width)
    else:
        # rle
        rle = ann['segmentation']
    return rle

def annToMask(self, ann, height, width):
    """
    Convert annotation which can be polygons, uncompressed RLE, or RLE to binary mask.
    :return: binary mask (numpy 2D array)
    """
    rle = self.annToRLE(ann, height, width)
    m = maskUtils.decode(rle)
    return m
